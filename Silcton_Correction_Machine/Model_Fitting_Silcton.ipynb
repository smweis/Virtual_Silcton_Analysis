# %% [markdown]
# # Participant (NEW) data: Analysis and Modeling

# %% [markdown]
# ## Some imports

# %%
import numpy as np
import pandas as pd
import scipy as sp

# %% [markdown]
# # Data Import - *participant level* Master DF

# %%
path = 'C:\\Users\\smwei\\Dropbox (UFL)\\Virtual_Ambler\\Fixing_Silcton\\OSF\\CleanedData\\masterDF.csv'
df = pd.read_csv(path, encoding = 'unicode_escape', sep = ",")

# %%
df.shape
# Out:
# (391, 35)

# %%
df.columns
# Out:
# Index(['good_pointing_coding_between', 'good_pointing_coding_within',
#        'bad_pointing_coding_between', 'bad_pointing_coding_within',
#        'participant', 'Original_Study_Number', 'SBSOD', 'gender', 'WRAT',
#        'Model_Building', 'Model_Building_A', 'Model_Building_B',
#        'K_Means_Across_All', 'Model_Building_Average_Within',
#        'Education_Numeric', 'New_or_Original', 'trackpad/mouse', 'Site',
#        'Experimenter ', 'NOTES', 'Age', 'Hispanic', 'Racial_Category',
#        'Racial_Category_Text', 'Education_Level', 'Education_Level_Text',
#        'Handedness', 'First_Language', 'Age_started_speaking_English',
#        'Participant_UUID_Silcton', 'date', 'MRT', 'good_pointing_coding_total',
#        'bad_pointing_coding_total', 'Color'],
#       dtype='object')

# %% [markdown]
# # Data Analysis - *participant level* Master DF

# %% [markdown]
# ## Preliminaries

# %%
# this section can be skipped, if it is not interesting. I just tried to understand the variables of the dataset

# %%
# variable
'good_pointing_coding_between', 
'good_pointing_coding_within',
'bad_pointing_coding_between', 
'bad_pointing_coding_within',
'participant', 
'Original_Study_Number', 
'SBSOD', 
'gender', 
'WRAT',
'Model_Building', 
'Model_Building_A', 
'Model_Building_B',
'K_Means_Across_All', 
'Model_Building_Average_Within',
'Education_Numeric', 
'New_or_Original', 
'trackpad/mouse', 
'Site',
'Experimenter ', 
'NOTES', 
'Age', 
'Hispanic', 
'Racial_Category',
'Racial_Category_Text', 
'Education_Level', 
'Education_Level_Text',
'Handedness', 
'First_Language', 
'Age_started_speaking_English',
'Participant_UUID_Silcton', 
'date', 
'MRT', 
'good_pointing_coding_total',
'bad_pointing_coding_total'
# Out:
# 'bad_pointing_coding_total'

# %%
# describing selected variables
x = 'good_pointing_coding_between'
df[x].describe()
# Out:
# count    391.000000
# mean      47.756307
# std       17.063426
# min        7.906232
# 25%       35.828410
# 50%       49.302534
# 75%       59.309263
# max       95.921731
# Name: good_pointing_coding_between, dtype: float64

# %%
# unique values of selected variables
df[x].unique()
# Out:
# array([78.22745098, 35.05201226, 46.90887339, 44.62639493, 63.83585475,
#        53.49372235, 32.6096    , 53.84209017, 79.03865112, 42.09230367,
#        16.20731014, 59.29779865, 48.02258835, 43.48360921, 55.36133232,
#        62.65897109, 53.72053447, 85.73268421, 47.64583759, 21.59453864,
#        64.80768702, 69.81721435, 70.7461531 , 32.56217582, 22.71944115,
#        39.30538438, 35.17623416, 30.92800995, 60.65936318, 85.04692758,
#        64.49438724, 65.4631086 , 20.74301032, 68.916295  , 34.10212938,
#        11.49146936, 58.44685133, 29.63482   , 72.89202848, 84.99432949,
#        19.42789421, 63.71403302, 33.2024758 , 95.92173064, 43.24751743,
#        34.01233105, 26.92121226, 60.1034374 , 37.4178535 , 52.37581618,
#        40.92923432, 40.3389091 , 64.16471648, 37.50174122, 64.03614699,
#        43.71615481, 60.53173786, 71.53772388, 70.96729528, 65.41163641,
#        13.16818849, 78.08033594, 71.56853896, 58.51154023, 74.35011617,
#        60.91462421, 25.72805344, 70.38575721, 49.65411112, 64.12035657,
#        31.40943686, 71.21549889, 75.57195189, 57.79398493, 20.70946725,
#        49.27468794, 36.089418  , 52.91311339, 23.88917392, 13.96938318,
#        35.3440322 , 47.76402897, 67.16807206, 30.79434025, 54.23042929,
#        48.62046835, 62.87550027, 74.74369462, 28.22483188, 67.86486123,
#        22.49858063, 20.21423536, 58.27469586, 55.86273947, 25.72080813,
#        44.36939342, 44.27300236, 40.70141722, 58.2407646 , 25.35548882,
#        58.34281127, 48.14764118, 15.3353117 , 54.84632016, 50.12060922,
#        52.54696715, 49.8522034 , 53.18127015, 56.01796775, 48.13266335,
#        58.72766532, 28.5369919 , 41.53944872, 18.27062605, 60.11742499,
#        49.81412383, 64.96644922, 54.83384457, 48.59768009, 26.4978102 ,
#        46.28846813, 47.86036847, 58.88772508, 52.18896101, 19.41641658,
#        23.42953232, 48.59248235, 55.31483806, 51.75064929, 45.14781479,
#        41.70316672, 69.06351602, 49.18427388, 22.08706945, 56.03287539,
#        38.20504991, 54.75005995, 54.76185905, 49.87112734, 53.55524499,
#        55.39852243, 38.88046242, 54.11555279, 55.09679958, 52.58549996,
#        55.41666858, 57.14384422, 32.6986447 , 27.59545236, 29.06367292,
#        31.78433969, 16.73855987, 47.92512472, 45.42380342, 49.42832053,
#        35.53729562, 54.72902674, 63.74695554, 39.44680372, 49.08853017,
#        47.87313121, 45.62423219, 65.28477798, 50.31994882, 38.38755751,
#        17.30812723, 43.97797322, 17.29117492, 56.20165261, 51.94877635,
#        44.9236335 , 53.17373154, 55.19632365, 21.46899195, 55.27919647,
#        63.26695605, 31.6837969 , 50.0866237 , 59.34420108, 23.32532268,
#        65.71674511, 53.39346302, 45.55216718, 46.41551055, 56.92602031,
#        20.4521953 , 27.46152477, 54.8634134 , 40.54925474, 60.88684241,
#        32.68813796, 49.31738138, 63.94444233, 41.92705429, 55.03643991,
#        48.50234794, 38.1644721 , 45.06632679, 30.59136758, 62.08474115,
#        41.25832922, 54.33451949, 48.29118238, 36.96998561, 45.43090681,
#        59.73787708, 41.72527662, 49.30253361, 42.88946389, 62.69560666,
#        52.11581305, 49.282268  , 29.20921732, 49.98054186, 31.70187482,
#        18.55554237, 55.66233369, 52.20189756, 53.87004178, 41.92974147,
#        38.178241  , 69.59390435, 54.19199468, 46.28096046, 41.65710667,
#        23.18709592, 47.36405582, 32.97249988, 60.56413537, 33.04537871,
#        44.89655757, 39.40075315, 43.39923305, 52.54521643, 45.00448883,
#        60.95663718, 62.9584667 , 34.06310722, 46.12770337, 65.97880196,
#        59.86098235, 12.07163162, 27.0339196 , 65.04202062, 42.20538625,
#        45.04047131, 28.13067335, 32.62471506, 33.0554312 , 51.73098953,
#        64.40151429, 11.14775142, 55.03744703, 48.14145281, 30.38886762,
#        51.05442791, 28.60892691, 70.86075566, 36.42465919, 44.35808374,
#        54.20217191, 60.73296656, 45.14402656, 32.4540373 , 62.61008976,
#        34.12973612, 64.30381667, 19.17250376, 17.73126841, 53.85987918,
#        27.31913472, 56.32704693, 65.88185449, 43.23424934, 13.14794315,
#        37.02880194, 51.94370642, 56.126884  , 52.66614058, 35.97832609,
#        56.01574259, 54.33652841, 46.552855  , 29.85311285, 42.65896545,
#        45.97130423, 49.15998513, 59.68193837, 41.71980369, 55.03840767,
#        52.03979303, 35.51492606, 49.08093105, 32.95097148,  7.90623215,
#        12.85241551, 63.0246759 , 58.87185838, 49.95231837, 54.61446656,
#        48.29246124, 42.81289609, 58.07716305, 60.12152081, 33.5109653 ,
#        63.62809581, 54.27032401, 54.43193361, 57.82169259, 55.5831962 ,
#        38.71963499, 54.80090376, 23.10815804, 24.60087034, 51.50974259,
#        59.72618051, 23.22251794, 29.73147883, 38.69515513, 54.38043319,
#        61.10404377, 35.67849397, 63.52497642, 57.3770059 , 36.53730683,
#        37.32520617, 52.27357978, 40.80331696, 32.44396679, 40.74354454,
#        52.29802912, 46.31463463, 57.98179517, 62.65782853, 41.34221786,
#        68.86288967, 26.90627268, 47.58851405, 87.62014103, 67.90325754,
#        55.72312136, 12.57544573, 89.92294979, 14.15062584, 38.40630595,
#        71.03304462, 77.15399253, 13.43462468, 72.91664962, 59.3207277 ,
#        55.71861097, 60.29682639, 56.76199637, 46.12453737, 22.14756338,
#        44.194931  , 61.64048508, 67.92918595, 32.07494587, 61.10611044,
#        11.08239818, 45.34197513, 13.02565993, 52.7169957 , 87.13437532,
#        75.54097389, 86.28011971, 79.74511329, 16.80755153, 15.36619949,
#        44.36976457, 60.22320675, 76.88957274, 57.97183228, 14.98145506,
#        58.49195502, 18.84186448, 75.18296835, 21.73238913, 50.97810847,
#        59.50027484, 63.7373334 , 90.96787167, 67.09835076, 39.57511139,
#        73.21006953, 75.35583069, 76.80298356, 21.35797152, 61.7613697 ,
#        60.95109069])

# %%
# plotting histograms of selected variables
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(df[x], bins = 30)
plt.show()

# %% [markdown]
# ## Biplots and correlations on NEW data

# %%
# let us have a look at selected biplots and compute correlations on NEW data

# %%
# variables to be considered
############################

# 'good_pointing_coding_between' 
# 'good_pointing_coding_within' 
# 'bad_pointing_coding_between'  
# 'bad_pointing_coding_within'  
# 'bad_pointing_coding_total'  
# 'bad_pointing_coding_total'  

x='good_pointing_coding_within'
y='bad_pointing_coding_within'  

# we consider only NEW data
df_b = df[df.New_or_Original=='New']

fig, ax = plt.subplots()
ax.scatter(df_b[x], df_b[y], edgecolors=(0, 0, 0))

#plt.plot(df_b[x], df_b[x]) # uncomment if you want display the bisector
#m, b = np.polyfit(df_b[x], df_b[y], 1) # uncomment if you want display the linear fit (watch out - what is x?)
#plt.plot(df_b[x], b+m*df_b[x])

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# correlations
from scipy.stats import spearmanr
from scipy.stats import pearsonr

corrp, ppvalue = pearsonr(df_b[x], df_b[y])
corrs, spvalue = spearmanr(df_b[x], df_b[y])
print('Pearson correlation and p-value', corrp)
print('Pearson p-value', ppvalue)
print()
print('Spearman correlation', corrs)
print('Spearman p-value', spvalue)
# Out:
# Pearson correlation and p-value 0.9651462521618237
# Pearson p-value 2.6297438663906038e-86
#
# Spearman correlation 0.9751565935518969
# Spearman p-value 8.226208685237988e-97

# %%
# distribution discrepancies
import matplotlib.pyplot as plt
# %matplotlib inline

delta = df_b[x]-df_b[y]

plt.hist(delta, bins = 30)
plt.show()

print(delta.describe())
# Out:
# count    1.470000e+02
# mean     6.838078e+00
# std      6.779133e+00
# min      5.000000e-10
# 25%      8.165802e-01
# 50%      5.206346e+00
# 75%      1.064070e+01
# max      3.583096e+01
# dtype: float64

# %% [markdown]
# # MODELING good_pointing_X=f(bad_pointing_X), on NEW participant data

# %%
# Following the "correction machine" idea, we predict good_pointing_X using bad_pointing_X on NEW data, only (147 samples).

# %% [markdown]
# ## Modeling data preparation

# %%
# chosen variables for modeling
chosen_variables = [
'bad_pointing_coding_within'
#'bad_pointing_coding_between'
#'bad_pointing_coding_total' 
]

# target
target = 'good_pointing_coding_within'

# %%
# IMPORTANT: according to the "correction machine logic", we 1) train on NEW data (where both good and bad pointing variables 
# are defined), and 2) we predict the "best guess" for the good_pointing_X variables on ORIGINAL data, 
# using the only information available, i.e., the bad_pointing_X variable.

# %%
# we train only on NEW data
df_train = df[df.New_or_Original=='New']
df_train = df_train[np.concatenate((chosen_variables, [target]), axis=0)]
df_train = df_train.dropna() # there are no NAs anyhow

# we test only on Original data
df_test = df[df.New_or_Original=='Original']
df_test = df_test[np.concatenate((chosen_variables, [target]), axis=0)]
df_test = df_test.dropna() # there are no NAs anyhow

print(df_train.shape)
print(df_test.shape)
# Out:
# (147, 2)
# (244, 2)

# %%
# with what are we going to model?
df_train.columns
# Out:
# Index(['bad_pointing_coding_within', 'good_pointing_coding_within'], dtype='object')

# %%
# training data
X_train = df_train.drop(columns=[target])
y_train = df_train[target]

# test data
X_test = df_test.drop(columns=[target])

X_train.columns
# Out:
# Index(['bad_pointing_coding_within'], dtype='object')

# %% [markdown]
# ## Modeling: univariate regression

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)

print('Linear regression coefficient:', reg.coef_)
print('Linear regression: intercept:', reg.intercept_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-21dd3b854a27> in <module>
# ----> 1 from sklearn import linear_model
#       2 reg = linear_model.LinearRegression()
#       3 reg.fit(X_train,y_train)
#       4
#       5 print('Linear regression coefficient:', reg.coef_)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# p-values: alternative approach. We use statsmodels
import statsmodels.api as sm
X_train_p = sm.add_constant(X_train)
mod = sm.OLS(y_train,X_train_p)

fii = mod.fit()
print(fii.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     good_pointing_coding_within   R-squared:                       0.932
# Model:                                     OLS   Adj. R-squared:                  0.931
# Method:                          Least Squares   F-statistic:                     1972.
# Date:                         Thu, 11 Mar 2021   Prob (F-statistic):           2.63e-86
# Time:                                 16:43:43   Log-Likelihood:                -428.29
# No. Observations:                          147   AIC:                             860.6
# Df Residuals:                              145   BIC:                             866.6
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -1.1836      0.692     -1.710      0.089      -2.552       0.184
# bad_pointing_coding_within     1.4468      0.033     44.407      0.000       1.382       1.511
# ==============================================================================
# Omnibus:                       48.838   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.357
# Skew:                           1.195   Prob(JB):                     8.35e-39
# Kurtosis:                       7.788   Cond. No.                         39.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train.columns
# Out:
# Index(['bad_pointing_coding_within'], dtype='object')

# %%
# PLOT PREDICTIONS VS TRUE VALUES
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots()
ax.scatter(X_train, y_train, edgecolors=(0, 0, 0))

plt.plot(X_train, reg.predict(X_train))
ax.set_xlabel('Pred')
ax.set_ylabel('True_y')
#path_png = 'INSERT PATH.png'
#figure.savefig(path_png, dpi=400)

plt.show()

# %%
# PLOT RESIDUALS
import numpy as np
import seaborn as sns

# Plot the residuals after fitting a linear model
resid= sns.residplot(x=reg.predict(X_train), y=y_train, lowess=False, label=None, color="b")
resid
figure = resid.get_figure()
#path_png = 'INSERT PATH.png'
#figure.savefig(path_png, dpi=400)

# %%
# HISTOGRAM RESIDUALS
# histogram of test scores
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(y_train-reg.predict(X_train), bins = 30)
#hist_png = 'INSERT PATH.png'
#plt.savefig(hist_png, dpi=400)
plt.show()

# %%
# fitting best model to whole dataset *IN SAMPLE*
reg.fit(X_train, y_train)

import sklearn
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

print('R^2 on whole dataset')
print(r2_score(y_train, reg.predict(X_train)))
print('---------------------')
print('MSE on whole dataset')
print(mean_squared_error(y_train, reg.predict(X_train)))
print('---------------------')
print('MAE on whole dataset')
print(mean_absolute_error(y_train, reg.predict(X_train)))
# Out:
# R^2 on whole dataset
# 0.9315072880620142
# ---------------------
# MSE on whole dataset
# 19.86988573174959
# ---------------------
# MAE on whole dataset
# 3.0296820261390356

# %% [markdown]
# ## Robustness of performance: cross-validation

# %%
# R2 is in-sample. Does it drop in presence of repeated cross-validation? If yes, can we quantify this drop? We do it
# for the univariate regression models.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedKFold

# scorer
###############################################################
from sklearn.metrics import make_scorer
from sklearn.metrics import r2_score

r2_scorer = make_scorer(r2_score)

# choice of scorer
scorer = r2_scorer

# random state
###############################################################
random_state=123
                            
# regressor (univariate linear regression)
###############################################################
clf = linear_model.LinearRegression()
    
# GRID SEARCH
##############################################################

# pipeline
pipe = Pipeline([('clf', clf)])

# PARAMETER GRID - we do nothing
##############################################################
param_grid = {}

# The repeated k-fold
##############################################################
n_folds=5     
n_repeats=100  

skfold = RepeatedKFold(n_splits=n_folds,
                       n_repeats=n_repeats,
                       random_state=random_state)

# GRID SEARCH
#############################################################
grid_clf = GridSearchCV(pipe, 
                        param_grid,
                        scoring=scorer,
                        cv=skfold, 
                        verbose=5)
                        
# RUNNING THE GRID
############################################
grid_clf.fit(X_train, y_train)
# Out:
# Fitting 500 folds for each of 1 candidates, totalling 500 fits
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.906, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.938, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.891, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.915, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.868, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.951, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.942, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.939, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.893, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.927, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.895, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.963, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.861, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.925, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.878, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.954, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.884, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.934, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.966, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.884, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.924, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.952, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.883, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.940, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.881, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.953, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.955, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.954, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.853, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.903, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.964, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.887, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.911, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.958, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.882, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.925, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.920, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.883, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.902, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.954, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.921, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.904, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.970, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.919, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.888, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.931, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.959, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.939, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.938, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.908, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.951, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.933, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.896, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.965, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.890, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.902, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.967, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.872, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.832, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.919, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.973, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.934, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.959, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.873, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.884, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.967, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.893, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.927, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.875, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.860, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.948, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.941, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.891, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.940, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.895, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.876, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.954, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.931, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.955, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.903, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.895, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.870, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.831, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.972, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.883, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.941, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.969, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.931, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.832, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.951, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.924, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.896, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.975, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.942, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.852, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.912, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.892, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.890, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.890, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.903, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.883, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.940, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.899, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.891, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.880, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.927, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.906, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.907, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.945, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.915, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.897, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.964, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.921, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.930, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.945, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.865, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.971, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.923, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.950, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.899, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.945, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.903, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.891, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.920, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.968, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.920, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.792, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.974, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.931, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.846, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.938, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.907, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.966, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.935, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.843, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.965, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.875, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.945, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.980, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.924, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.921, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.915, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.950, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.952, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.944, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.843, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.890, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.899, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.941, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.939, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.892, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.948, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.918, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.868, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.894, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.939, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.948, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.928, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.931, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.911, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.866, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.958, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.901, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.951, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.935, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.865, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.891, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.934, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.908, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.935, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.920, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.958, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.920, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.972, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.848, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.804, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.980, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.959, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.892, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.888, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.933, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.877, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.927, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.964, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.918, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.935, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.881, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.888, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.920, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.884, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.989, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.924, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.982, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.856, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.906, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.978, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.918, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.893, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.904, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.957, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.908, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.874, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.955, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.933, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.924, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.889, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.951, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.878, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.910, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.973, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.927, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.894, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.942, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.967, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.904, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.937, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.945, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.927, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.910, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.858, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.928, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.969, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.952, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.938, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.923, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.848, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.962, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.966, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.934, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.887, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.845, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.965, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.845, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.963, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.892, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.950, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.907, total=   0.0s
# [CV]  ................................................................
# ...
# [CV]  ................................................................
# [CV] .................................... , score=0.908, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.922, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.910, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.934, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.865, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.912, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.949, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.847, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.970, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.962, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.928, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.917, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.870, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.893, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.963, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.915, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.928, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.970, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.861, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.898, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.928, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.967, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.903, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.836, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.923, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.955, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.939, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.958, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.876, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.887, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.950, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.958, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.921, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.922, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.968, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.878, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.913, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.930, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.926, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.928, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.923, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.934, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.948, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.936, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.908, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.893, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.911, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.956, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.961, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.960, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.867, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.901, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.892, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.905, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.901, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.894, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.974, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.929, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.894, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.962, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.924, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.909, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.962, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.888, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.916, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.943, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.939, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.862, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.914, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.957, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.955, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.966, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.940, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.907, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.886, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.952, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.834, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.964, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.947, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.965, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.896, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.963, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.907, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.942, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.946, total=   0.0s
# [CV]  ................................................................
# [CV] .................................... , score=0.860, total=   0.0s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    1.9s finished
# GridSearchCV(cv=RepeatedKFold(n_repeats=100, n_splits=5, random_state=123),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('clf',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(r2_score), verbose=5)

# %%
# COLLECTING RESULTS
##############################################################

# best estimator
clf_b = grid_clf.best_estimator_

# print results
print('-------------------------------------------------------')
print('-------------------------------------------------------')
print('Best parameters:', grid_clf.best_params_)
print('-------------------------------------------------------')
print('-------------------------------------------------------')
print('Mean performance (and standard deviation):')
print(grid_clf.cv_results_['mean_test_score'][grid_clf.best_index_])
print(grid_clf.cv_results_['std_test_score'][grid_clf.best_index_])
# Out:
# -------------------------------------------------------
# -------------------------------------------------------
# Best parameters: {}
# -------------------------------------------------------
# -------------------------------------------------------
# Mean performance (and standard deviation):
# 0.9230358075187582
# 0.03309816802440321

# %%
# double chek on the model
clf_b.fit(X_train, y_train)

print('R^2 on whole dataset')
print(r2_score(y_train, clf_b.predict(X_train)))
print('---------------------')
print('MSE on whole dataset')
print(mean_squared_error(y_train, clf_b.predict(X_train)))
print('---------------------')
print('MAE on whole dataset')
print(mean_absolute_error(y_train, clf_b.predict(X_train)))
# Out:
# R^2 on whole dataset
# 0.9315072880620142
# ---------------------
# MSE on whole dataset
# 19.86988573174959
# ---------------------
# MAE on whole dataset
# 3.0296820261390356

# %% [markdown]
# ## Modeling: easy regression tree

# %%
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeRegressor

# scorer
###############################################################
from sklearn.metrics import make_scorer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2_scorer = make_scorer(r2_score)
mean_sq_scorer = make_scorer(mean_squared_error, greater_is_better=False) # important: the higher, the worse
mean_ab_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

# choice of scorer
#scorer = mean_sq_scorer
scorer = r2_scorer

# random state
###############################################################
random_state=123
                            
# regressor
###############################################################
clf = DecisionTreeRegressor(random_state=random_state)
    
# GRID SEARCH
##############################################################

# pipeline
pipe = Pipeline([('clf', clf)])

# PARAMETER GRID
##############################################################
param_grid = {'clf__max_depth': [1, 2, 3, 4, 5, 6, 7]}

# # THE REPEATED K FOLD
# #########################################
n_folds=5     #5
n_repeats=100  #50

skfold = RepeatedKFold(n_splits=n_folds,
                        n_repeats=n_repeats,
                        random_state=random_state)

# GRID SEARCH
#############################################
grid_clf = GridSearchCV(pipe, 
                        param_grid,
                        scoring=scorer,
                        cv=skfold, 
                        verbose=5)
                        
# RUNNING THE GRID
############################################
grid_clf.fit(X_train, y_train)
# Out:
# Fitting 500 folds for each of 7 candidates, totalling 3500 fits
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.592, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.628, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.516, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.606, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.458, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.319, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.561, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.493, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.655, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.555, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.608, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.651, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.613, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.491, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.567, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.575, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.583, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.433, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.337, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.582, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.601, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.576, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.541, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.632, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.342, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.142, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.619, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.523, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.550, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.610, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.560, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.370, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.441, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.655, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.462, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.576, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.632, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.442, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.424, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.601, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.602, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.606, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.654, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.457, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.604, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.629, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.575, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.492, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.127, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.627, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.558, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.500, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.578, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.667, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.559, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.698, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.474, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.384, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.285, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.504, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.542, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.606, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.538, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.638, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.563, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.622, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.619, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.546, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.551, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.689, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.664, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.394, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.589, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.590, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.479, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.580, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.633, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.466, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.568, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.447, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.382, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.653, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.618, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.646, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.535, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.631, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.585, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.560, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.380, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.540, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.577, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.661, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.529, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.504, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.497, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.487, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.522, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.583, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.561, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.629, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.420, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.516, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.572, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.526, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.566, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.467, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.218, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.610, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.637, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.312, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.430, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.502, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.244, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.589, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.555, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.499, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.277, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.685, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.465, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.603, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.626, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.554, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.543, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.405, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.581, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.656, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.499, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.685, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.350, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.556, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.472, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.621, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.517, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.566, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.702, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.139, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.602, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.478, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.665, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.358, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.611, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.454, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.631, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.562, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.251, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.493, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.663, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.426, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.535, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.549, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.614, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.530, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.567, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.563, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.594, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.460, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.501, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.612, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.531, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.432, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.607, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.673, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.509, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.498, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.624, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.545, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.487, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.510, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.627, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.504, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.608, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.539, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.529, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.643, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.413, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.678, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.555, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.114, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.467, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.521, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.630, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] ................... clf__max_depth=1, score=-0.251, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.553, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.663, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.520, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.351, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.610, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.267, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.660, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.543, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.507, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.563, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.380, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.514, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.713, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.613, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.631, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.373, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.660, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.609, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.646, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.674, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.554, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.455, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.156, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.573, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.657, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.687, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.402, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.611, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.517, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.594, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.631, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.626, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.532, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.119, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.375, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.599, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.469, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.627, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.721, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.578, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.501, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.039, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.591, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.610, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.536, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.617, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.338, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.595, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.404, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.622, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.632, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.564, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.276, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.384, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.642, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.506, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.621, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.551, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.645, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.440, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.661, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.507, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.565, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.661, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.620, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.449, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.672, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.230, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.508, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.302, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.601, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.635, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.069, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.617, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.402, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.508, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.640, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.525, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.641, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.580, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.678, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.494, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.565, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.477, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.617, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.612, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.386, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.572, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.448, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.421, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.679, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.612, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.618, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.620, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.537, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.625, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.445, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.647, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.606, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.496, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.483, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.600, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.661, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.615, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.612, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.553, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.323, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.589, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.630, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.604, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.584, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.551, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.455, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.467, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.459, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.651, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.622, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.636, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.463, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.502, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.397, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.571, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.665, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.382, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.513, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.521, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.648, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.660, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.567, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.618, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.118, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.518, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.611, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.605, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.608, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.566, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.561, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.480, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.649, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.647, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.556, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.570, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.407, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.593, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.199, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.581, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.570, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.603, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.479, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.598, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.676, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# [CV] .................... clf__max_depth=1, score=0.486, total=   0.0s
# [CV] clf__max_depth=1 ................................................
# ...
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.858, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.809, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.845, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.882, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.862, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.908, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.754, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.953, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.922, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.868, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.849, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.873, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.839, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.856, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.826, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.859, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.910, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.887, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.831, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.906, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.834, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.817, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.833, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.901, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.948, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.864, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.842, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.741, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.791, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.944, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.933, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.873, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.854, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.863, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.858, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.867, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.689, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.878, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.930, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.868, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.797, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.863, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.857, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.833, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.792, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.918, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.891, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.892, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.810, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.865, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.898, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.829, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.860, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.919, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.845, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.789, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.900, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.910, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.848, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.769, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.885, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.940, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.892, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.805, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.864, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.712, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.771, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.850, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.905, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.829, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.927, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.864, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.836, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.881, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.910, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.857, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.869, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.903, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.746, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.899, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.929, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.914, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.835, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.838, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.928, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.736, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.934, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.844, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.862, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.816, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.876, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.781, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.926, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.799, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.918, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.834, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.944, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.886, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.829, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.872, total=   0.0s
# [CV] clf__max_depth=7 ................................................
# [CV] .................... clf__max_depth=7, score=0.822, total=   0.0s
# [Parallel(n_jobs=1)]: Done 3500 out of 3500 | elapsed:   12.5s finished
# GridSearchCV(cv=RepeatedKFold(n_repeats=100, n_splits=5, random_state=123),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('clf',
#                                         DecisionTreeRegressor(ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features=None,
#                                                               max_leaf_nodes=None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               min_samples_leaf=1,
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=0.0,
#                                                               presort='deprecated',
#                                                               random_state=123,
#                                                               splitter='best'))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'clf__max_depth': [1, 2, 3, 4, 5, 6, 7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(r2_score), verbose=5)

# %%
# COLLECTING RESULTS
##############################################################

# best estimator
clf_b = grid_clf.best_estimator_

# print results
print('-------------------------------------------------------')
print('-------------------------------------------------------')
print('Best parameters:', grid_clf.best_params_)
print('-------------------------------------------------------')
print('-------------------------------------------------------')
print('Mean performance (and standard deviation):')
print(grid_clf.cv_results_['mean_test_score'][grid_clf.best_index_])
print(grid_clf.cv_results_['std_test_score'][grid_clf.best_index_])
# Out:
# -------------------------------------------------------
# -------------------------------------------------------
# Best parameters: {'clf__max_depth': 4}
# -------------------------------------------------------
# -------------------------------------------------------
# Mean performance (and standard deviation):
# 0.8936365265042457
# 0.03902980764168308

# %%
clf_b.named_steps['clf'].tree_.node_count
# Out:
# 31

# %%
# analysis tree
clf = clf_b.named_steps['clf']

n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
stack = [(0, 0)]  # start with the root node id (0) and its depth (0)
while len(stack) > 0:
    # `pop` ensures each node is only visited once
    node_id, depth = stack.pop()
    node_depth[node_id] = depth

    # If the left and right child of a node is not the same we have a split
    # node
    is_split_node = children_left[node_id] != children_right[node_id]
    # If a split node, append left and right children and depth to `stack`
    # so we can loop through them
    if is_split_node:
        stack.append((children_left[node_id], depth + 1))
        stack.append((children_right[node_id], depth + 1))
    else:
        is_leaves[node_id] = True

print("The binary tree structure has {n} nodes and has "
      "the following tree structure:\n".format(n=n_nodes))
for i in range(n_nodes):
    if is_leaves[i]:
        print("{space}node={node} is a leaf node.".format(
            space=node_depth[i] * "\t", node=i))
    else:
        print("{space}node={node} is a split node: "
              "go to node {left} if X[:, {feature}] <= {threshold} "
              "else to node {right}.".format(
                  space=node_depth[i] * "\t",
                  node=i,
                  left=children_left[i],
                  feature=feature[i],
                  threshold=threshold[i],
                  right=children_right[i]))
# Out:
# The binary tree structure has 31 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 0] <= 17.023366928100586 else to node 16.
# 	node=1 is a split node: go to node 2 if X[:, 0] <= 9.849149703979492 else to node 9.
# 		node=2 is a split node: go to node 3 if X[:, 0] <= 6.717329263687134 else to node 6.
# 			node=3 is a split node: go to node 4 if X[:, 0] <= 4.100853204727173 else to node 5.
# 				node=4 is a leaf node.
# 				node=5 is a leaf node.
# 			node=6 is a split node: go to node 7 if X[:, 0] <= 8.271501541137695 else to node 8.
# 				node=7 is a leaf node.
# 				node=8 is a leaf node.
# 		node=9 is a split node: go to node 10 if X[:, 0] <= 12.768805503845215 else to node 13.
# 			node=10 is a split node: go to node 11 if X[:, 0] <= 10.196305274963379 else to node 12.
# 				node=11 is a leaf node.
# 				node=12 is a leaf node.
# 			node=13 is a split node: go to node 14 if X[:, 0] <= 14.554952621459961 else to node 15.
# 				node=14 is a leaf node.
# 				node=15 is a leaf node.
# 	node=16 is a split node: go to node 17 if X[:, 0] <= 31.591395378112793 else to node 24.
# 		node=17 is a split node: go to node 18 if X[:, 0] <= 21.02597713470459 else to node 21.
# 			node=18 is a split node: go to node 19 if X[:, 0] <= 17.163935661315918 else to node 20.
# 				node=19 is a leaf node.
# 				node=20 is a leaf node.
# 			node=21 is a split node: go to node 22 if X[:, 0] <= 29.26368522644043 else to node 23.
# 				node=22 is a leaf node.
# 				node=23 is a leaf node.
# 		node=24 is a split node: go to node 25 if X[:, 0] <= 37.622188568115234 else to node 28.
# 			node=25 is a split node: go to node 26 if X[:, 0] <= 35.45694160461426 else to node 27.
# 				node=26 is a leaf node.
# 				node=27 is a leaf node.
# 			node=28 is a split node: go to node 29 if X[:, 0] <= 46.458906173706055 else to node 30.
# 				node=29 is a leaf node.
# 				node=30 is a leaf node.
